# %% [markdown]
# # Simple Regression - Predicting Values from Data
#
# This notebook will teach you how to use machine learning to predict one value from other values in your data.
#
# **What we'll learn:**
# 1. Choose what we want to predict (target) and what to use for prediction (features)
# 2. Split our data into training and testing sets
# 3. Try 3 different regression models
# 4. Compare which model works best
# 5. Make predictions on new data
#
# **Example:**
# We might predict salary based on experience, job type, and company size.
#
# **Instructions:**
# - Make sure you have clean data from the previous notebook
# - Run each cell one by one
# - Choose your own features to experiment with!

# %%
# Import libraries for machine learning
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder, StandardScaler

print("Libraries imported successfully!")
print("Ready to build regression models!")
print("📊 Available preprocessing tools:")
print("- One-hot encoding: pd.get_dummies()")
print("- Label encoding: LabelEncoder()")
print("- Feature scaling: StandardScaler()")
# Out:
# Libraries imported successfully!
# Ready to build regression models!
# 📊 Available preprocessing tools:
# - One-hot encoding: pd.get_dummies()
# - Label encoding: LabelEncoder()
# - Feature scaling: StandardScaler()

# %% [markdown]
# ## 1. Load Your Data
#
# First, let's load our clean data from the previous notebook.

# %%
# Load your clean data
df = pd.read_csv('content/cleaned_data.csv')

print(f"Data loaded successfully!")
print(f"Shape: {df.shape[0]} rows × {df.shape[1]} columns")

# Look at the data
print("\nFirst few rows:")
df.head()
# Out:
# Data loaded successfully!
# Shape: 64620 rows × 11 columns
#
# First few rows:
#    work_year experience_level employment_type           job_title  salary  \
# 0       2025               SE              FT  Solutions Engineer  214000
# 1       2025               MI              FT       Data Engineer  158800
# 2       2025               MI              FT       Data Engineer  139200
# 3       2025               EN              FT       Data Engineer   90000
# 4       2025               EN              FT       Data Engineer   80000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         158800                 AU             0
# 2             USD         139200                 AU             0
# 3             USD          90000                 US             0
# 4             USD          80000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               AU            M
# 2               AU            M
# 3               US            M
# 4               US            M

# %% [markdown]
# ## 2. Choose What to Predict and What to Use for Prediction
#
# We need to choose:
# - **Target (Y)**: What we want to predict (must be a number)
# - **Features (X)**: What we'll use to make the prediction (can be numbers or categories)

# %%
# Look at our columns to decide what to predict
print("Available columns in our dataset:")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col} - {df[col].dtype}")

print("\nNumerical columns (good for prediction targets):")
numerical_cols = df.select_dtypes(include=[np.number]).columns.tolist()
print(numerical_cols)

print("\nAll columns (can be used as features):")
all_cols = df.columns.tolist()
print(all_cols)
# Out:
# Available columns in our dataset:
# 1. work_year - int64
# 2. experience_level - object
# 3. employment_type - object
# 4. job_title - object
# 5. salary - int64
# 6. salary_currency - object
# 7. salary_in_usd - int64
# 8. employee_residence - object
# 9. remote_ratio - int64
# 10. company_location - object
# 11. company_size - object
#
# Numerical columns (good for prediction targets):
# ['work_year', 'salary', 'salary_in_usd', 'remote_ratio']
#
# All columns (can be used as features):
# ['work_year', 'experience_level', 'employment_type', 'job_title', 'salary', 'salary_currency', 'salary_in_usd', 'employee_residence', 'remote_ratio', 'company_location', 'company_size']

# %%
# CHOOSE YOUR TARGET AND FEATURES HERE
# Change these to match your data and what you want to predict

# What we want to predict (must be numerical)
target_column = 'salary_in_usd'  # Change this to your target column

# What we'll use to make predictions (choose 2-5 columns)
feature_columns = ['experience_level', 'job_title', 'company_location']  # Change these

print(f"We want to predict: {target_column}")
print(f"Using these features: {feature_columns}")

# Check if our choices are valid
if target_column not in df.columns:
    print(f"ERROR: {target_column} not found in data")
else:
    print(f"✓ Target column '{target_column}' found")

missing_features = [col for col in feature_columns if col not in df.columns]
if missing_features:
    print(f"ERROR: These features not found: {missing_features}")
else:
    print("✓ All feature columns found")
# Out:
# We want to predict: salary_in_usd
# Using these features: ['experience_level', 'job_title', 'company_location']
# ✓ Target column 'salary_in_usd' found
# ✓ All feature columns found

# %% [markdown]
# ## 3. Prepare the Data for Machine Learning
#
# We need to prepare our data so the computer can understand it. This involves:
# 1. **Encoding categorical features** - Converting text to numbers
# 2. **Scaling numerical features** - Making sure all features are on similar scales
#
# **Two main encoding methods:**
# - **One-hot encoding**: Creates separate columns for each category (good for few categories)
# - **Label encoding**: Assigns numbers to categories (good for many categories)

# %%
# Create our target (Y) and features (X)
y = df[target_column]  # What we want to predict
X = df[feature_columns]  # What we'll use to predict

print("Data before preparation:")
print(f"Target shape: {y.shape}")
print(f"Features shape: {X.shape}")
print(f"Features data types:\n{X.dtypes}")

# Identify categorical and numerical features
categorical_features = X.select_dtypes(include=['object']).columns.tolist()
numerical_features = X.select_dtypes(include=[np.number]).columns.tolist()

print(f"\nCategorical features: {categorical_features}")
print(f"Numerical features: {numerical_features}")

# CHOOSE YOUR ENCODING METHOD HERE
# Option 1: One-hot encoding (creates separate columns for each category)
# Option 2: Label encoding (assigns numbers to categories)

ENCODING_METHOD = "one_hot"  # Change to "label" for label encoding

print(f"\n🔧 Using {ENCODING_METHOD} encoding for categorical features...")

if ENCODING_METHOD == "one_hot":
    # One-hot encoding: Good when you have few categories per feature
    X_encoded = pd.get_dummies(X, columns=categorical_features, drop_first=True)
    print(f"✓ One-hot encoding applied")
    print(f"  Original features: {X.shape[1]}")
    print(f"  After encoding: {X_encoded.shape[1]} features")

elif ENCODING_METHOD == "label":
    # Label encoding: Good when you have many categories or ordinal data
    X_encoded = X.copy()
    label_encoders = {}

    for feature in categorical_features:
        le = LabelEncoder()
        X_encoded[feature] = le.fit_transform(X[feature].astype(str))
        label_encoders[feature] = le
        print(f"  {feature}: {len(le.classes_)} categories → 0 to {len(le.classes_)-1}")

    print(f"✓ Label encoding applied")
    print(f"  Features remain: {X_encoded.shape[1]} (same as original)")

print(f"\nNew feature names: {list(X_encoded.columns)}")

# Remove any rows with missing values
mask = ~(X_encoded.isnull().any(axis=1) | y.isnull())
X_clean = X_encoded[mask]
y_clean = y[mask]

print(f"\nAfter removing missing values:")
print(f"Final dataset size: {len(X_clean)} rows")
print(f"Features: {X_clean.shape[1]} columns")
# Out:
# Data before preparation:
# Target shape: (64620,)
# Features shape: (64620, 3)
# Features data types:
# experience_level    object
# job_title           object
# company_location    object
# dtype: object
#
# Categorical features: ['experience_level', 'job_title', 'company_location']
# Numerical features: []
#
# 🔧 Using one_hot encoding for categorical features...
# ✓ One-hot encoding applied
#   Original features: 3
#   After encoding: 486 features
#
# New feature names: ['experience_level_EX', 'experience_level_MI', 'experience_level_SE', 'job_title_AI Content Writer', 'job_title_AI Data Engineer', 'job_title_AI Data Scientist', 'job_title_AI Developer', 'job_title_AI Engineer', 'job_title_AI Engineering Lead', 'job_title_AI Engineering Manager', 'job_title_AI Governance Lead', 'job_title_AI Governance Specialist', 'job_title_AI Lead', 'job_title_AI Machine Learning Engineer', 'job_title_AI Product Lead', 'job_title_AI Product Manager', 'job_title_AI Product Owner', 'job_title_AI Programmer', 'job_title_AI Research Engineer', 'job_title_AI Research Scientist', 'job_title_AI Researcher', 'job_title_AI Scientist', 'job_title_AI Software Development Engineer', 'job_title_AI Software Engineer', 'job_title_AI Solution Architect', 'job_title_AI Solutions Specialist', 'job_title_AI Specialist', 'job_title_AI Strategist', 'job_title_AI Tech Lead', 'job_title_AWS Data Architect', 'job_title_Account Executive', 'job_title_Actuarial Analyst', 'job_title_Actuary', 'job_title_Admin & Data Analyst', 'job_title_Advanced Data Analyst', 'job_title_Algorithm Developer', 'job_title_Alternance', 'job_title_Analyst', 'job_title_Analytics Analyst', 'job_title_Analytics Engineer', 'job_title_Analytics Engineering Manager', 'job_title_Analytics Lead', 'job_title_Analytics Specialist', 'job_title_Application Developer', 'job_title_Applied AI ML Lead', 'job_title_Applied Data Scientist', 'job_title_Applied Machine Learning Engineer', 'job_title_Applied Machine Learning Scientist', 'job_title_Applied Research Scientist', 'job_title_Applied Scientist', 'job_title_Architect', 'job_title_Artificial Intelligence Engineer', 'job_title_Associate', 'job_title_Automation Engineer', 'job_title_Autonomous Vehicle Technician', 'job_title_Azure Data Engineer', 'job_title_BI & Data Analyst', 'job_title_BI Analyst', 'job_title_BI Data Analyst', 'job_title_BI Data Engineer', 'job_title_BI Developer', 'job_title_BI Engineer', 'job_title_Backend Developer', 'job_title_Backend Engineer', 'job_title_Backend Software Engineer', 'job_title_Bear Robotics', 'job_title_Big Data Analyst', 'job_title_Big Data Architect', 'job_title_Big Data Developer', 'job_title_Big Data Engineer', 'job_title_Bioinformatician', 'job_title_Bioinformatics Scientist', 'job_title_Bioinformatics Specialist', 'job_title_Business Analyst', 'job_title_Business Data Analyst', 'job_title_Business Development Manager', 'job_title_Business Development Representative', 'job_title_Business Insights Manager', 'job_title_Business Intelligence', 'job_title_Business Intelligence Analyst', 'job_title_Business Intelligence Consultant', 'job_title_Business Intelligence Data Analyst', 'job_title_Business Intelligence Developer', 'job_title_Business Intelligence Engineer', 'job_title_Business Intelligence Lead', 'job_title_Business Intelligence Manager', 'job_title_Business Intelligence Specialist', 'job_title_CRM Data Analyst', 'job_title_Chatbot Developer', 'job_title_Cheminformatics Scientist', 'job_title_Cientista de Dados', 'job_title_Clinical Aide', 'job_title_Clinical Data Operator', 'job_title_Cloud Architect', 'job_title_Cloud Data Architect', 'job_title_Cloud Data Engineer', 'job_title_Cloud Database Administrator', 'job_title_Cloud Database Engineer', 'job_title_Cloud Developer', 'job_title_Cloud Engineer', 'job_title_Compliance Data Analyst', 'job_title_Computational Biologist', 'job_title_Computational Scientist', 'job_title_Computer Vision Engineer', 'job_title_Computer Vision Software Engineer', 'job_title_Consultant', 'job_title_Consultant Data Engineer', 'job_title_Controls Engineer', 'job_title_Conversational AI Designer', 'job_title_Copywriter', 'job_title_Creative Technologist', 'job_title_Customer Success Engineer', 'job_title_Customer Success Manager', 'job_title_Data & Analytics Analyst', 'job_title_Data Analist', 'job_title_Data Analysis', 'job_title_Data Analysis Specialist', 'job_title_Data Analyst', 'job_title_Data Analyst Lead', 'job_ti ...
#
# After removing missing values:
# Final dataset size: 64620 rows
# Features: 486 columns

# %% [markdown]
# ### 🤔 Understanding Encoding Methods
#
# **When to use One-Hot Encoding:**
# - ✅ Few categories per feature (2-10 categories)
# - ✅ Categories have no natural order (e.g., colors, countries)
# - ✅ You want the model to treat each category independently
# - ❌ Avoid with many categories (creates too many features)
#
# **When to use Label Encoding:**
# - ✅ Many categories per feature (10+ categories)
# - ✅ Categories have natural order (e.g., low/medium/high)
# - ✅ Memory/speed is important (fewer features)
# - ❌ Avoid when categories have no meaningful order (model may assume ranking)
#
# **Experiment:** Try changing `ENCODING_METHOD` above and see how it affects your results!

# %%
# STEP 2: Feature Scaling (Normalization)
# This ensures all features are on similar scales (important for Linear Regression!)

APPLY_SCALING = True  # Change to False if you don't want scaling

if APPLY_SCALING:
    print("🔧 APPLYING FEATURE SCALING")
    print("=" * 40)

    # Show feature ranges before scaling (only for numerical features)
    print("Feature statistics BEFORE scaling:")

    # For one-hot encoded data, show value counts instead of ranges
    if ENCODING_METHOD == "one_hot":
        print(f"One-hot encoded features: {X_clean.shape[1]} binary columns")
        print(f"Data type: {X_clean.dtypes.iloc[0]} (0s and 1s)")
        print(f"Sample feature values: {X_clean.iloc[0].sum()} features = 1 for first row")
    else:
        # For label encoded data, we can show ranges
        feature_ranges_before = X_clean.max() - X_clean.min()
        print("Feature ranges:")
        print(feature_ranges_before.describe())

    # Apply StandardScaler (mean=0, std=1)
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_clean)
    X_scaled = pd.DataFrame(X_scaled, columns=X_clean.columns, index=X_clean.index)

    # Show feature statistics after scaling
    print(f"\nFeature statistics AFTER scaling:")
    print(f"Mean values (should be ≈ 0): {X_scaled.mean().mean():.6f}")
    print(f"Standard deviation (should be ≈ 1): {X_scaled.std().mean():.6f}")
    feature_ranges_after = X_scaled.max() - X_scaled.min()
    print(f"Average range after scaling: {feature_ranges_after.mean():.3f}")

    print(f"\n✓ Feature scaling applied!")
    print(f"  All features now have mean ≈ 0 and std ≈ 1")
    print(f"  This helps Linear Regression perform better")

    # Use scaled features
    X_final = X_scaled

else:
    print("⚠️  Skipping feature scaling")
    if ENCODING_METHOD == "one_hot":
        print("Note: One-hot encoded features are already 0/1, scaling less critical")
    else:
        print("Note: Linear Regression may perform poorly with unscaled features")
    X_final = X_clean

print(f"\n📊 FINAL PREPARED DATA:")
print(f"Features shape: {X_final.shape}")
print(f"Target shape: {y_clean.shape}")
print(f"Ready for machine learning!")
# Out:
# 🔧 APPLYING FEATURE SCALING
# ========================================
# Feature statistics BEFORE scaling:
# One-hot encoded features: 486 binary columns
# Data type: bool (0s and 1s)
# Sample feature values: 3 features = 1 for first row
#
# Feature statistics AFTER scaling:
# Mean values (should be ≈ 0): -0.000000
# Standard deviation (should be ≈ 1): 1.000008
# Average range after scaling: 96.719
#
# ✓ Feature scaling applied!
#   All features now have mean ≈ 0 and std ≈ 1
#   This helps Linear Regression perform better
#
# 📊 FINAL PREPARED DATA:
# Features shape: (64620, 486)
# Target shape: (64620,)
# Ready for machine learning!

# %% [markdown]
# ## 4. Split Data into Training and Testing Sets
#
# We'll use 80% of our data to train the model and 20% to test how well it works.

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X_final, y_clean,   # Use our prepared features and clean target
    test_size=0.2,      # Use 20% for testing
    random_state=42     # For reproducible results
)

print("Data split successfully!")
print(f"Training set: {X_train.shape[0]} rows")
print(f"Testing set: {X_test.shape[0]} rows")
print(f"Features: {X_train.shape[1]} columns")

print(f"\nTarget variable summary:")
print(f"Training target range: {y_train.min():.0f} to {y_train.max():.0f}")
print(f"Testing target range: {y_test.min():.0f} to {y_test.max():.0f}")

if APPLY_SCALING:
    print(f"\n✓ Using scaled features for training")
    print(f"  Feature means ≈ 0, standard deviations ≈ 1")
else:
    print(f"\n⚠️  Using unscaled features for training")
# Out:
# Data split successfully!
# Training set: 51696 rows
# Testing set: 12924 rows
# Features: 486 columns
#
# Target variable summary:
# Training target range: 15000 to 800000
# Testing target range: 15000 to 800000
#
# ✓ Using scaled features for training
#   Feature means ≈ 0, standard deviations ≈ 1

# %% [markdown]
# ## 5. Train Three Different Regression Models
#
# Let's try three different types of models and see which works best!

# %%
# Model 1: Linear Regression (draws a straight line through the data)
print("Training Model 1: Linear Regression")
model1 = LinearRegression()
model1.fit(X_train, y_train)

# Make predictions
y_pred1 = model1.predict(X_test)

# Calculate performance
mse1 = mean_squared_error(y_test, y_pred1)
r2_1 = r2_score(y_test, y_pred1)

print(f"✓ Linear Regression (Ridge) trained!")
print(f"  Mean Squared Error: {mse1:.2f}")
print(f"  R² Score: {r2_1:.3f} (higher is better, max = 1.0)")
# Out:
# Training Model 1: Linear Regression
# ✓ Linear Regression (Ridge) trained!
#   Mean Squared Error: 4266880259.38
#   R² Score: 0.279 (higher is better, max = 1.0)

# %%
# Model 2: Decision Tree (makes decisions like a flowchart)
print("Training Model 2: Decision Tree")
model2 = DecisionTreeRegressor(random_state=42, max_depth=10)
model2.fit(X_train, y_train)

# Make predictions
y_pred2 = model2.predict(X_test)

# Calculate performance
mse2 = mean_squared_error(y_test, y_pred2)
r2_2 = r2_score(y_test, y_pred2)

print(f"✓ Decision Tree trained!")
print(f"  Mean Squared Error: {mse2:.2f}")
print(f"  R² Score: {r2_2:.3f} (higher is better, max = 1.0)")
# Out:
# Training Model 2: Decision Tree
# ✓ Decision Tree trained!
#   Mean Squared Error: 4536532182.32
#   R² Score: 0.233 (higher is better, max = 1.0)

# %%
# Model 3: Random Forest (combines many decision trees)
print("Training Model 3: Random Forest")
model3 = RandomForestRegressor(n_estimators=100, random_state=42, max_depth=10)
model3.fit(X_train, y_train)

# Make predictions
y_pred3 = model3.predict(X_test)

# Calculate performance
mse3 = mean_squared_error(y_test, y_pred3)
r2_3 = r2_score(y_test, y_pred3)

print(f"✓ Random Forest trained!")
print(f"  Mean Squared Error: {mse3:.2f}")
print(f"  R² Score: {r2_3:.3f} (higher is better, max = 1.0)")
# Out:
# Training Model 3: Random Forest
# ✓ Random Forest trained!
#   Mean Squared Error: 4471097312.95
#   R² Score: 0.244 (higher is better, max = 1.0)

# %% [markdown]
# ## 6. Compare the Models
#
# Let's see which model performed best on our test data!

# %%
# Compare all models
results = pd.DataFrame({
    'Model': ['Linear Regression', 'Decision Tree', 'Random Forest'],
    'Mean_Squared_Error': [mse1, mse2, mse3],
    'R2_Score': [r2_1, r2_2, r2_3]
})

print("🏆 MODEL COMPARISON RESULTS")
print("=" * 50)
print(results.to_string(index=False, float_format='%.3f'))

# Find the best model
best_model_idx = results['R2_Score'].idxmax()
best_model_name = results.loc[best_model_idx, 'Model']
best_r2 = results.loc[best_model_idx, 'R2_Score']

print(f"\n🥇 WINNER: {best_model_name}")
print(f"   R² Score: {best_r2:.3f}")

print(f"\nHow to interpret R² Score:")
print(f"- 1.0 = Perfect predictions")
print(f"- 0.8+ = Very good")
print(f"- 0.6+ = Good")
print(f"- 0.4+ = Okay")
print(f"- Below 0.4 = Needs improvement")
# Out:
# 🏆 MODEL COMPARISON RESULTS
# ==================================================
#             Model  Mean_Squared_Error  R2_Score
# Linear Regression      4266880259.381     0.279
#     Decision Tree      4536532182.324     0.233
#     Random Forest      4471097312.950     0.244
#
# 🥇 WINNER: Linear Regression
#    R² Score: 0.279
#
# How to interpret R² Score:
# - 1.0 = Perfect predictions
# - 0.8+ = Very good
# - 0.6+ = Good
# - 0.4+ = Okay
# - Below 0.4 = Needs improvement

# %% [markdown]
# ## 7. Visualise the Results
#
# Let's create plots to see how well our models performed.

# %%
# Plot actual vs predicted values for each model
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

models = [
    ('Linear Regression', y_pred1),
    ('Decision Tree', y_pred2),
    ('Random Forest', y_pred3)
]

for i, (name, predictions) in enumerate(models):
    axes[i].scatter(y_test, predictions, alpha=0.6)
    axes[i].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
    axes[i].set_xlabel('Actual Values')
    axes[i].set_ylabel('Predicted Values')
    axes[i].set_title(f'{name}')
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("How to read these plots:")
print("- Points close to the red line = good predictions")
print("- Points far from the red line = poor predictions")
print("- Tighter cluster around the line = better model")
# Out:
# How to read these plots:
# - Points close to the red line = good predictions
# - Points far from the red line = poor predictions
# - Tighter cluster around the line = better model

# %%
# Show which features are most important (for Random Forest)
print("🔍 FEATURE IMPORTANCE (Random Forest)")
print("This shows which features matter most for predictions:")
print("=" * 60)

feature_importance = pd.DataFrame({
    'Feature': X_final.columns,  # Use the final prepared features
    'Importance': model3.feature_importances_
}).sort_values('Importance', ascending=False)

print(feature_importance.to_string(index=False, float_format='%.3f'))

# Plot feature importance
plt.figure(figsize=(10, 6))
plt.barh(range(len(feature_importance)), feature_importance['Importance'])
plt.yticks(range(len(feature_importance)), feature_importance['Feature'])
plt.xlabel('Importance')
plt.title('Feature Importance in Random Forest Model')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

print(f"\n💡 Understanding Feature Importance:")
print(f"- Higher values = more important for predictions")
print(f"- Random Forest calculates this automatically")
print(f"- Sum of all importances = 1.0")
if ENCODING_METHOD == "one_hot":
    print(f"- One-hot encoded features may split importance across columns")
# Out:
# 🔍 FEATURE IMPORTANCE (Random Forest)
# This shows which features matter most for predictions:
# ============================================================
#                                             Feature  Importance
#                                 company_location_US       0.269
#                                 experience_level_SE       0.170
#                                 experience_level_EX       0.104
#                                 experience_level_MI       0.072
#                              job_title_Data Analyst       0.066
#                       job_title_Engineering Manager       0.049
#                                 company_location_CA       0.041
#                 job_title_Machine Learning Engineer       0.041
#                                   job_title_Analyst       0.027
#                        job_title_Research Scientist       0.024
#                         job_title_Software Engineer       0.024
#                         job_title_Research Engineer       0.019
#                                 company_location_GB       0.012
#                           job_title_Data Specialist       0.012
#                                 company_location_AU       0.010
#                                  job_title_Engineer       0.007
#                           job_title_Product Manager       0.006
#                job_title_ML Infrastructure Engineer       0.004
#                              job_title_Head of Data       0.004
#                                 job_title_Associate       0.003
#                              job_title_Data Manager       0.003
#                                   job_title_Manager       0.002
#              job_title_Enterprise Account Executive       0.002
#                                job_title_Head of AI       0.002
#                                 company_location_DE       0.002
#                           job_title_Insight Analyst       0.002
#                                 company_location_NL       0.001
#                             job_title_AI Researcher       0.001
#                      job_title_Quantitative Analyst       0.001
#                   job_title_Quantitative Researcher       0.001
#                                 company_location_CZ       0.001
#                              job_title_AI Scientist       0.001
#                         job_title_Applied Scientist       0.001
#                  job_title_Head of Machine Learning       0.001
#                                job_title_Consultant       0.001
#                            job_title_Data Scientist       0.001
#                               job_title_AI Engineer       0.001
#                                 company_location_CH       0.001
#                                 company_location_IE       0.001
#                             job_title_Data Analysis       0.001
#             job_title_Analytics Engineering Manager       0.001
#                                 company_location_EG       0.000
#                        job_title_Head of Applied AI       0.000
#                             job_title_Data Engineer       0.000
#                                 company_location_MX       0.000
#                                 company_location_QA       0.000
#                        job_title_Research Team Lead       0.000
#            job_title_Director of Product Management       0.000
#                                 company_location_SK       0.000
#                                 company_location_NZ       0.000
#                        job_title_Staff Data Analyst       0.000
#                         job_title_Account Executive       0.000
#                      job_title_Quant Options Trader       0.000
#                        job_title_Analytics Engineer       0.000
#                                 company_location_IN       0.000
#                                 job_title_Architect       0.000
#                                  job_title_Director       0.000
#                  job_title_Principal Data Scientist       0.000
#              job_title_Director of Machine Learning       0.000
#                                 job_title_Tech Lead       0.000
#                           job_title_Prompt Engineer       0.000
#                        job_title_AI Product Manager       0.000
#                     job_title_Business Intelligence       0.000
#                                 company_location_SG       0.000
#                            job_title_Data Architect       0.000
#                job_title_Machine Learning Scientist       0.000
#                                 company_location_LT       0.000
#                                 company_location_VE       0.000
#                   job_title_Computational Biologist       0.000
#             job_title_Business Intelligence Analyst       0.000
#                                 company_location_FR       0.000
#                        job_title_Research Assistant       0.000
#                        job_title_Software Developer       0.000
#                         job_title_Platform Engineer       0.000
#                                 job_title_Developer       0.000
#                       job_title_Cloud Data Engineer       0.000
#                    job_title_Software Data Engineer       0.000
#                             job_title_AI Programmer       0.000
#                                 company_location_IL       0.000
#                                 company_location_PL       0.000
#                                 company_location_AT       0.000
#                          job_title_Business Analyst       0.000
#                          job_title_Systems Engineer       0.000
#        job_title_Applied Machine Learning Scientist       0.000
#                         job_title_AI Data Scientist       0.000
#                                 company_location_BE       0.000
#                                 company_location_ZA       0.000
#                    job_title_Deep Learning Engineer       0.000
#                                 company_location_HK       0.000
#                                 company_location_PR       0.000
#                           job_title_Data Governance       0.000
#                    job_title_Statistical Programmer       0.000
#                        job_title_Solutions Engineer       0.000
#                               job_title_QA Engineer       0.000
#                              job_title_AI Developer       0.000
#             job_title_Software Development Engineer       0.000
#                                 company_location_JP       0.000
#                        job_title_Solution Architect       0.000
#                       job_title_Solutions Architect       0.000
#                                 company_location_PH       0.000
#                                 company_location_ES       0.000
#                            job_title_MLOps Engineer       0.000
#                       job_title_Full Stack Engineer       0.000
#                      job_title_Full Stack Developer       0.000
#               job_title_Machine Learning Researcher       0.000
#                          job_title_Backend Engineer       0.000
#                                 company_location_PT       0.000
#          job_title_Artificial Intelligence Engineer       0.000
#                   job_title_Data Management Analyst       0.000
#                       job_title_People Data Analyst       0.000
#         job_title_Computer Vision Software Engineer       0.000
#                                 company_location_IT       0.000
#           job_title_Business Intelligence Developer       0.000
#                      job_title_Data Governance Lead       0.000
#                    job_title_Master Data Management       0.000
#                                 company_location_GR       0.000
#                          job_title_Research Analyst       0.000
#                                 company_location_AR       0.000
#                      job_title_AI Software Engineer       0.000
#        job_title_Machine Learning Software Engineer       0.000
#       job_title_Principal Machine Learning Engineer       0.000
#                        job_title_Data Product Owner       0.000
#                        job_title_Cientista de Dados       0.000
#                                 company_location_BG       0.000
#                                 company_location_CL       0.000
#                                 company_location_CR       0.000
#                       job_title_Postdoctoral Fellow       0.000
#                          job_title_Python Developer       0.000
#                                 company_location_LV       0.000
#                   job_title_Data Governance Analyst       0.000
#                           job_title_DevOps Engineer       0.000
#                     job_title_Technology Integrator       0.000
#                      job_title_AI Research Engineer       0.000
#                         job_title_Robotics Engineer       0.000
#                          job_title_Product Designer       0.000
#                           job_title_Data Management       0.000
#                            job_title_Cloud Engineer       0.000
#                              job_title_BI Developer       0.000
#                                 company_location_CN       0.000
#                      job_title_Analytics Specialist       0.000
#                           job_title_Product Analyst       0.000
#                                 company_location_RU       0.000
#                              job_title_Risk Analyst       0.000
#                    job_title_Applied Data Scientist       0.000
#                        job_title_Software Architect       0.000
#                 job_title_Site Reliability Engineer       0.000
#         job_title_Safety Data Management Specialist       0.000
#                             job_title_SAS Developer       0.000
#                job_title_Robotics Software Engineer       0.000
#                                job_title_Researcher       0.000
#                            job_title_Analytics Lead       0.000
#                     job_title_Research Professional       0.000
#                        job_title_Applied AI ML Lead       0.000
#             job_title_Software Development Director       0.000
#                     job_title_Research Data Manager       0.000
#                         job_title_Solution Engineer       0.000
#                        job_title_Sales Data Analyst       0.000
#                        job_title_Research Associate       0.000
#                                     job_title_Stage       0.000
#           job_title_Staff Machine Learning Engineer       0.000
#                      job_title_Staff Data Scientist       0.000
#                     job_title_Application Developer       0.000
#                         job_title_Security Engineer       0.000
#                   job_title_Principal Data Engineer       0.000
#                                 company_location_UA       0.000
#                        job_title_Principal Engineer       0.000
#                      job_title_Principal Researcher       0.000
#                       job_title_Principal Scientist       0.000
#              job_title_Principal Software Architect       0.000
#          job_title_Principal Statistical Programmer       0.000
#                      job_title_Product Data Analyst       0.000
#                                 company_location_TW       0.000
#                       job_title_Security Researcher       0.000
#                          job_title_Network Engineer       0.000
#                    job_title_Platform Data Engineer       0.000
#                      job_title_Post Doctoral Fellow       0.000
#              job_title_Postdoctoral Research Fellow       0.000
#                   job_title_Postdoctoral Researcher       0.000
#                                  job_title_Power BI       0.000
#                    job_title_Power BI Administrator       0.000
#                        job_title_Power BI Architect       0.000
#                       job_title_Power BI Consultant       0.000
#                        job_title_Power BI Developer       0.000
#                              job_title_NLP Engineer       0.000
#          job_title_Sales Development Representative       0.000
#                            job_title_Sales Engineer       0.000
#                  job_title_Salesforce Administrator       0.000
#                     job_title_Scala Spark Developer       0.000
#                             job_title_Product Owner       0.000
#                        job_title_Product Specialist       0.000
#                         job_title_Analytics Analyst       0.000
#                           job_title_Psychometrician       0.000
#                                job_title_Alternance       0.000
#                  job_title_Principal Data Architect       0.000
#                       job_title_Algorithm Developer       0.000
#                    job_title_Quantitative Developer       0.000
#             job_title_Quantitative Research Analyst       0.000
#                     job_title_Advanced Data Analyst       0.000
#                       job_title_Quantitative Trader       0.000
#                             job_title_RPA Developer       0.000
#                      job_title_Admin & Data Analyst       0.000
#                           job_title_Pricing Analyst       0.000
# job_title_Principal Application Delivery Consultant       0.000
#                    job_title_Principal Data Analyst       0.000
#                              job_title_Quant Trader       0.000
#                  job_title_AI Governance Specialist       0.000
#                                 company_location_NG       0.000
#                                   job_title_AI Lead       0.000
#              job_title_AI Machine Learning Engineer       0.000
#                                 company_location_GH       0.000
#                                 company_location_GI       0.000
#                                 company_location_HN       0.000
#                                 company_location_HR       0.000
#                                 company_location_HU       0.000
#                                 company_location_ID       0.000
#                              job_title_Statistician       0.000
#                                 company_location_TR       0.000
#                         job_title_AI Content Writer       0.000
#                                 company_location_IQ       0.000
#                                 company_location_IR       0.000
#                                 company_location_TH       0.000
#                                 company_location_CO       0.000
#                                 company_location_CY       0.000
#                                 company_location_SV       0.000
#                                 company_location_SI       0.000
#                                 company_location_DK       0.000
#                                 company_location_JM       0.000
#                          job_title_AI Data Engineer       0.000
#                                 company_location_NO       0.000
#                                 company_location_OM       0.000
#                                 company_location_PA       0.000
#                                 company_location_PE       0.000
#                                 company_location_PK       0.000
#                       job_title_AI Engineering Lead       0.000
#                    job_title_AI Engineering Manager       0.000
#                                 company_location_VN       0.000
#                                 company_location_XK       0.000
#                                 company_location_MU       0.000
#                                 company_location_ZM       0.000
#                                 company_location_JO       0.000
#                                 company_location_KE       0.000
#                                 company_location_KR       0.000
#                                 company_location_LB       0.000
#                                 company_location_LS       0.000
#                        job_title_AI Governance Lead       0.000
#                                 company_location_LU       0.000
#                                 company_location_MD       0.000
#                                 company_location_MK       0.000
#                                 company_location_MT       0.000
#                           job_title_AI Product Lead       0.000
#                                 company_location_AS       0.000
#                                 company_location_RS       0.000
#                                 company_location_RO       0.000
#                                 company_location_BA       0.000
#                     job_title_AI Research Scientist       0.000
#                          job_title_AI Product Owner       0.000
#                           job_title_Power BI Expert       0.000
#                      job_title_System Administrator       0.000
#                           job_title_System Engineer       0.000
#                     job_title_Systems Administrator       0.000
#                                 company_location_DO       0.000
#                         job_title_Tableau Developer       0.000
#         job_title_Applied Machine Learning Engineer       0.000
#                            job_title_Tech Lead Data       0.000
#                       job_title_Technical Architect       0.000
#                            job_title_Technical Lead       0.000
#                       job_title_Technical Recruiter       0.000
#                      job_title_Technical Specialist       0.000
#                job_title_Technical Support Engineer       0.000
#              job_title_Technical Support Specialist       0.000
#                          job_title_Technical Writer       0.000
#                                 company_location_MY       0.000
#                                 company_location_DZ       0.000
#                                 company_location_EC       0.000
#                                 company_location_EE       0.000
#                                 company_location_SE       0.000
#                                 company_location_FI       0.000
#                                 company_location_SA       0.000
#          job_title_AI Software Development Engineer       0.000
#                     job_title_AI Solution Architect       0.000
#                   job_title_AI Solutions Specialist       0.000
#                             job_title_AI Specialist       0.000
#                                 company_location_AM       0.000
#                              job_title_AI Tech Lead       0.000
#                        job_title_AWS Data Architect       0.000
#                         job_title_Actuarial Analyst       0.000
#                                   job_title_Actuary       0.000
#                                 company_location_BR       0.000
#                                 company_location_BS       0.000
#                                 company_location_CD       0.000
#                                 company_location_CF       0.000
#                                   job_title_Trainee       0.000
#                             job_title_Web Developer       0.000
#                                 company_location_AE       0.000
#                             job_title_AI Strategist       0.000
#               job_title_Data Integration Specialist       0.000
#                           job_title_Data Integrator       0.000
#                    job_title_Data Integrity Analyst       0.000
#                 job_title_Data Integrity Specialist       0.000
#                                 job_title_Data Lead       0.000
#                 job_title_Data Management Associate       0.000
#                job_title_Data Management Consultant       0.000
#               job_title_Data Management Coordinator       0.000
#                    job_title_Data Management Expert       0.000
#                      job_title_Data Management Lead       0.000
#                    job_title_Marketing Data Analyst       0.000
#                            job_title_Data Archivist       0.000
#                           job_title_Data Consultant       0.000
#                      job_title_Data DevOps Engineer       0.000
#                            job_title_Data Developer       0.000
#                  job_title_Bioinformatics Scientist       0.000
#                 job_title_Data Governance Architect       0.000
#                job_title_Data Governance Consultant       0.000
#                  job_title_Data Governance Engineer       0.000
#                   job_title_Data Governance Manager       0.000
#                job_title_Data Governance Specialist       0.000
#              job_title_Data Infrastructure Engineer       0.000
#                   job_title_Data Management Manager       0.000
#                     job_title_Business Data Analyst       0.000
#                  job_title_Data Scientist Associate       0.000
#                     job_title_Data Scientist Expert       0.000
#                       job_title_Data Scientist Lead       0.000
#                    job_title_Data Scientist Manager       0.000
#                job_title_Data Management Specialist       0.000
#                 job_title_Bioinformatics Specialist       0.000
#                              job_title_Data Modeler       0.000
#                           job_title_Data Operations       0.000
#                   job_title_Data Operations Analyst       0.000
#                 job_title_Data Operations Associate       0.000
#                     job_title_Data Integration Lead       0.000
#                      job_title_Data Operations Lead       0.000
#                   job_title_Data Operations Manager       0.000
#                job_title_Data Operations Specialist       0.000
#                             job_title_Data Operator       0.000
#                    job_title_Data Pipeline Engineer       0.000
#                    job_title_Data Platform Engineer       0.000
#                      job_title_Data Product Analyst       0.000
#                         job_title_Data Product Lead       0.000
#                      job_title_Data Product Manager       0.000
#                job_title_Data Integration Developer       0.000
#                 job_title_Data Integration Engineer       0.000
#                  job_title_Data Operations Engineer       0.000
#                        job_title_Big Data Architect       0.000
#                  job_title_Consultant Data Engineer       0.000
#                         job_title_Controls Engineer       0.000
#                job_title_Conversational AI Designer       0.000
#                                job_title_Copywriter       0.000
#                     job_title_Creative Technologist       0.000
#                 job_title_Customer Success Engineer       0.000
#          job_title_Business Intelligence Consultant       0.000
#        job_title_Business Intelligence Data Analyst       0.000
#            job_title_Business Intelligence Engineer       0.000
#                job_title_Business Intelligence Lead       0.000
#                  job_title_Data Integration Analyst       0.000
#          job_title_Business Intelligence Specialist       0.000
#                          job_title_CRM Data Analyst       0.000
#                         job_title_Chatbot Developer       0.000
#                 job_title_Cheminformatics Scientist       0.000
#                             job_title_Clinical Aide       0.000
#                    job_title_Clinical Data Operator       0.000
#                           job_title_Cloud Architect       0.000
#                      job_title_Cloud Data Architect       0.000
#                          job_title_Big Data Analyst       0.000
#                 job_title_Backend Software Engineer       0.000
#                             job_title_Bear Robotics       0.000
#             job_title_Business Intelligence Manager       0.000
#              job_title_Data Integration Coordinator       0.000
#                  job_title_Customer Success Manager       0.000
#                  job_title_Data & Analytics Analyst       0.000
#                              job_title_Data Analist       0.000
#                          job_title_Bioinformatician       0.000
#                  job_title_Data Analysis Specialist       0.000
#                         job_title_Data Analyst Lead       0.000
#                  job_title_Data Analytics Associate       0.000
#           job_title_Data Analytics Business Partner       0.000
#                 job_title_Data Analytics Consultant       0.000
#                  job_title_Data Analytics Developer       0.000
#                  job_title_Computer Vision Engineer       0.000
#                       job_title_Data Analytics Lead       0.000
#                    job_title_Data Analytics Manager       0.000
#                 job_title_Data Analytics Specialist       0.000
#                  job_title_Data Analytics Team Lead       0.000
#                         job_title_Big Data Engineer       0.000
#              job_title_Cloud Database Administrator       0.000
#                   job_title_Cloud Database Engineer       0.000
#                           job_title_Cloud Developer       0.000
#                   job_title_Compliance Data Analyst       0.000
#                        job_title_Big Data Developer       0.000
#                   job_title_Computational Scientist       0.000
#                   job_title_Data Analytics Engineer       0.000
#        job_title_Machine Learning Platform Engineer       0.000
#         job_title_Machine Learning Quality Engineer       0.000
#        job_title_Machine Learning Research Engineer       0.000
#                          job_title_BI Data Engineer       0.000
#                           job_title_BI Data Analyst       0.000
#                         job_title_Head of Marketing       0.000
#                   job_title_Infrastructure Engineer       0.000
#                                job_title_BI Analyst       0.000
#                    job_title_Integration Specialist       0.000
#                            job_title_Java Developer       0.000
#                              job_title_LLM Engineer       0.000
#                    job_title_Data Science Tech Lead       0.000
#                              job_title_Lead Analyst       0.000
#                        job_title_Lead Data Analysis       0.000
#                         job_title_Lead Data Analyst       0.000
#                        job_title_Lead Data Engineer       0.000
#                      job_title_Lead Data Management       0.000
#                       job_title_Lead Data Scientist       0.000
#                             job_title_Lead Engineer       0.000
#               job_title_Elasticsearch Administrator       0.000
#    job_title_Encounter Data Management Professional       0.000
#                         job_title_BI & Data Analyst       0.000
#                       job_title_Azure Data Engineer       0.000
#                          job_title_Lead AI Engineer       0.000
#                       job_title_Power BI Specialist       0.000
#                         job_title_Backend Developer       0.000
#               job_title_Machine Learning Specialist       0.000
#                job_title_Machine Learning Tech Lead       0.000
#                   job_title_Machine Vision Engineer       0.000
#                               job_title_BI Engineer       0.000
#                   job_title_Manager Data Management       0.000
#                         job_title_Marketing Analyst       0.000
#               job_title_Marketing Analytics Manager       0.000
#                   job_title_Marketing Data Engineer       0.000
#                  job_title_Marketing Data Scientist       0.000
#     job_title_Machine Learning Performance Engineer       0.000
#                    job_title_Master Data Specialist       0.000
#                 job_title_Member of Technical Staff       0.000
#            job_title_Lead Machine Learning Engineer       0.000
#                              job_title_ML Scientist       0.000
#                job_title_Machine Learning Architect       0.000
#                job_title_Machine Learning Developer       0.000
#  job_title_Machine Learning Infrastructure Engineer       0.000
#                     job_title_Machine Learning Lead       0.000
#                  job_title_Machine Learning Manager       0.000
#           job_title_Machine Learning Model Engineer       0.000
#                  job_title_Machine Learning Modeler       0.000
#                 job_title_Marketing Science Partner       0.000
#                           job_title_Data Strategist       0.000
#                        job_title_Data Strategy Lead       0.000
#                     job_title_Data Strategy Manager       0.000
#                            job_title_Data Team Lead       0.000
#                job_title_Data Visualization Analyst       0.000
#               job_title_Data Visualization Designer       0.000
#              job_title_Data Visualization Developer       0.000
#               job_title_Data Visualization Engineer       0.000
#                 job_title_Data Visualization Expert       0.000
#             job_title_Data Visualization Specialist       0.000
#             job_title_Data and Analytics Consultant       0.000
#                                 job_title_Executive       0.000
#           job_title_Data and Reporting Professional       0.000
#                          job_title_DataOps Engineer       0.000
#                      job_title_Data Quality Analyst       0.000
#                     job_title_Data Quality Engineer       0.000
#                       job_title_Data Quality Expert       0.000
#                         job_title_Data Quality Lead       0.000
#                      job_title_Data Quality Manager       0.000
#                   job_title_Data Quality Specialist       0.000
#                             job_title_Data Reporter       0.000
#                    job_title_Data Reporting Analyst       0.000
#                 job_title_Data Reporting Specialist       0.000
#                job_title_Data and Reporting Analyst       0.000
#       job_title_Experienced Quantitative Strategist       0.000
#                      job_title_Finance Data Analyst       0.000
#                    job_title_Financial Data Analyst       0.000
#                         job_title_Frontend Engineer       0.000
#                        job_title_Fullstack Engineer       0.000
#                           job_title_GenAI Architect       0.000
#             job_title_Autonomous Vehicle Technician       0.000
#                       job_title_Automation Engineer       0.000
#             job_title_Head of Business Intelligence       0.000
#                    job_title_Database Administrator       0.000
#                       job_title_Databricks Engineer       0.000
#                              job_title_Data Steward       0.000
#                  job_title_Deep Learning Researcher       0.000
#                               job_title_DevOps Lead       0.000
#                        job_title_Developer Advocate       0.000
#                job_title_Applied Research Scientist       0.000
#         job_title_Director of Business Intelligence       0.000
#                 job_title_Business Insights Manager       0.000
#       job_title_Business Development Representative       0.000
#                             job_title_ETL Developer       0.000
#                              job_title_ETL Engineer       0.000
#                                 job_title_Economist       0.000
#              job_title_Business Development Manager       0.000
#                        job_title_Decision Scientist       0.000
# 💡 Understanding Feature Importance:
# - Higher values = more important for predictions
# - Random Forest calculates this automatically
# - Sum of all importances = 1.0
# - One-hot encoded features may split importance across columns

# %% [markdown]
# ## 8. Make Predictions on New Data
#
# Now let's use our best model to make predictions!

# %%
# Use the best model to make predictions
models = [model1, model2, model3]
best_model = models[best_model_idx]

print(f"Using {best_model_name} for predictions")

# Example: Make predictions on a few test cases
print("\n📊 SAMPLE PREDICTIONS")
print("=" * 50)

# Show first 5 predictions vs actual values
sample_size = min(5, len(X_test))
sample_predictions = best_model.predict(X_test.iloc[:sample_size])

for i in range(sample_size):
    actual = y_test.iloc[i]
    predicted = sample_predictions[i]
    error = abs(actual - predicted)

    print(f"Case {i+1}:")
    print(f"  Actual: {actual:.0f}")
    print(f"  Predicted: {predicted:.0f}")
    print(f"  Error: {error:.0f}")
    print()

print("💡 TIP: You can use this model to predict new values!")
print("Just create a new row with the same features and use model.predict()")
# Out:
# Using Linear Regression for predictions
#
# 📊 SAMPLE PREDICTIONS
# ==================================================
# Case 1:
#   Actual: 120000
#   Predicted: 152799
#   Error: 32799
#
# Case 2:
#   Actual: 205412
#   Predicted: 192225
#   Error: 13187
#
# Case 3:
#   Actual: 265000
#   Predicted: 187008
#   Error: 77992
#
# Case 4:
#   Actual: 163500
#   Predicted: 142907
#   Error: 20593
#
# Case 5:
#   Actual: 50000
#   Predicted: 82275
#   Error: 32275
#
# 💡 TIP: You can use this model to predict new values!
# Just create a new row with the same features and use model.predict()

# %% [markdown]
# ## 9. Summary and Next Steps
#
# **🎉 Congratulations! You've built your first regression models!**
#
# **What we learned:**
# - How to choose target variables and features
# - How to prepare data for machine learning
# - How to split data into training and testing sets
# - How to train 3 different regression models
# - How to compare model performance
# - How to make predictions on new data
#
# **Key takeaways:**
# - **Linear Regression**: Simple, interpretable, good for linear relationships
# - **Decision Tree**: Handles non-linear patterns, easy to understand
# - **Random Forest**: Often the most accurate, combines many trees
#
# **Try this next:**
# 1. Change the target variable to predict something else
# 2. Add or remove features to see how it affects performance
# 3. Try different train/test split ratios
# 4. Experiment with different datasets
#
# **Remember:**
# - Higher R² score = better model (closer to 1.0)
# - Always test on unseen data
# - More data usually means better models
# - Feature selection matters!

# %% [markdown]
# ## 10. Bonus: Regularized Linear Regression
#
# Sometimes Linear Regression can have problems with certain features. Let's try regularized versions that are more robust!

# %%
# Import regularized regression models
from sklearn.linear_model import Ridge, Lasso

print("What is regularization?")
print("- Regularization helps prevent overfitting")
print("- It makes models more stable with difficult features")
print("- Ridge and Lasso are two common types")
print("- They work better when you have many features or correlated features")
print("\nLet's try them!")
# Out:
# What is regularization?
# - Regularization helps prevent overfitting
# - It makes models more stable with difficult features
# - Ridge and Lasso are two common types
# - They work better when you have many features or correlated features
#
# Let's try them!

# %%
# Model 4: Ridge Regression (Linear Regression with L2 regularization)
print("Training Model 4: Ridge Regression")
model4 = Ridge(alpha=1.0, random_state=42)
model4.fit(X_train, y_train)

# Make predictions
y_pred4 = model4.predict(X_test)

# Calculate performance
mse4 = mean_squared_error(y_test, y_pred4)
r2_4 = r2_score(y_test, y_pred4)

print(f"✓ Ridge Regression trained!")
print(f"  Mean Squared Error: {mse4:.2f}")
print(f"  R² Score: {r2_4:.3f} (higher is better, max = 1.0)")
print(f"  Ridge helps when features are correlated")
# Out:
# Training Model 4: Ridge Regression
# ✓ Ridge Regression trained!
#   Mean Squared Error: 4266536990.40
#   R² Score: 0.279 (higher is better, max = 1.0)
#   Ridge helps when features are correlated

# %%
# Model 5: Lasso Regression (Linear Regression with L1 regularization)
print("Training Model 5: Lasso Regression")
model5 = Lasso(alpha=1.0, random_state=42, max_iter=1000)
model5.fit(X_train, y_train)

# Make predictions
y_pred5 = model5.predict(X_test)

# Calculate performance
mse5 = mean_squared_error(y_test, y_pred5)
r2_5 = r2_score(y_test, y_pred5)

print(f"✓ Lasso Regression trained!")
print(f"  Mean Squared Error: {mse5:.2f}")
print(f"  R² Score: {r2_5:.3f} (higher is better, max = 1.0)")
print(f"  Lasso automatically selects important features")
# Out:
# Training Model 5: Lasso Regression
# ✓ Lasso Regression trained!
#   Mean Squared Error: 4266931746.52
#   R² Score: 0.279 (higher is better, max = 1.0)
#   Lasso automatically selects important features
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.625e+13, tolerance: 3.120e+10
#   model = cd_fast.enet_coordinate_descent(

# %%
# Compare ALL models including regularized ones
all_results = pd.DataFrame({
    'Model': ['Linear Regression', 'Decision Tree', 'Random Forest', 'Ridge Regression', 'Lasso Regression'],
    'Mean_Squared_Error': [mse1, mse2, mse3, mse4, mse5],
    'R2_Score': [r2_1, r2_2, r2_3, r2_4, r2_5]
})

print("🏆 COMPLETE MODEL COMPARISON")
print("=" * 60)
print(all_results.to_string(index=False, float_format='%.3f'))

# Find the best model overall
best_overall_idx = all_results['R2_Score'].idxmax()
best_overall_name = all_results.loc[best_overall_idx, 'Model']
best_overall_r2 = all_results.loc[best_overall_idx, 'R2_Score']

print(f"\n🥇 OVERALL WINNER: {best_overall_name}")
print(f"   R² Score: {best_overall_r2:.3f}")

print(f"\n📚 When to use each model:")
print(f"- Linear Regression: Simple relationships, interpretable")
print(f"- Ridge Regression: When features are correlated, more stable")
print(f"- Lasso Regression: Automatic feature selection, sparse solutions")
print(f"- Decision Tree: Non-linear patterns, easy to explain")
print(f"- Random Forest: Best overall performance, handles everything")
# Out:
# 🏆 COMPLETE MODEL COMPARISON
# ============================================================
#             Model  Mean_Squared_Error  R2_Score
# Linear Regression      4266880259.381     0.279
#     Decision Tree      4536532182.324     0.233
#     Random Forest      4471097312.950     0.244
#  Ridge Regression      4266536990.402     0.279
#  Lasso Regression      4266931746.519     0.279
#
# 🥇 OVERALL WINNER: Ridge Regression
#    R² Score: 0.279
#
# 📚 When to use each model:
# - Linear Regression: Simple relationships, interpretable
# - Ridge Regression: When features are correlated, more stable
# - Lasso Regression: Automatic feature selection, sparse solutions
# - Decision Tree: Non-linear patterns, easy to explain
# - Random Forest: Best overall performance, handles everything

# %%
# Show how Lasso selects features (sets some coefficients to zero)
print("🔍 FEATURE SELECTION BY LASSO")
print("=" * 50)

# Get coefficients for Ridge and Lasso
ridge_coef = pd.DataFrame({
    'Feature': X_final.columns,  # Use final prepared features
    'Ridge_Coefficient': model4.coef_
})

lasso_coef = pd.DataFrame({
    'Feature': X_final.columns,  # Use final prepared features
    'Lasso_Coefficient': model5.coef_
})

# Combine and show
feature_coef = pd.merge(ridge_coef, lasso_coef, on='Feature')
feature_coef['Lasso_Selected'] = (feature_coef['Lasso_Coefficient'] != 0)

print("Feature coefficients (Ridge vs Lasso):")
print(feature_coef.to_string(index=False, float_format='%.3f'))

# Count features selected by Lasso
selected_features = feature_coef['Lasso_Selected'].sum()
total_features = len(feature_coef)

print(f"\n📊 Lasso selected {selected_features} out of {total_features} features")
print(f"Features with coefficient = 0 are considered unimportant by Lasso")

if ENCODING_METHOD == "one_hot":
    print(f"\n💡 With one-hot encoding:")
    print(f"- Lasso might select only some categories from a feature")
    print(f"- This helps identify which specific categories matter most")
elif ENCODING_METHOD == "label":
    print(f"\n💡 With label encoding:")
    print(f"- Lasso selects entire features (not individual categories)")
    print(f"- Coefficients show direction and strength of relationship")
# Out:
# 🔍 FEATURE SELECTION BY LASSO
# ==================================================
# Feature coefficients (Ridge vs Lasso):
#                                             Feature  Ridge_Coefficient  Lasso_Coefficient  Lasso_Selected
#                                 experience_level_EX          13302.871          13300.153            True
#                                 experience_level_MI           8132.514           8126.327            True
#                                 experience_level_SE          21301.372          21305.761            True
#                         job_title_AI Content Writer           -990.430           -968.339            True
#                          job_title_AI Data Engineer           -548.266           -531.457            True
#                         job_title_AI Data Scientist           -895.620           -858.433            True
#                              job_title_AI Developer          -2016.816          -1874.615            True
#                               job_title_AI Engineer          -3512.684          -3159.395            True
#                       job_title_AI Engineering Lead           -343.111           -330.953            True
#                    job_title_AI Engineering Manager             70.721             85.957            True
#                        job_title_AI Governance Lead           -215.470           -198.584            True
#                  job_title_AI Governance Specialist           -790.063           -761.224            True
#                                   job_title_AI Lead           -381.406           -320.707            True
#              job_title_AI Machine Learning Engineer           -370.169           -349.703            True
#                           job_title_AI Product Lead            220.476            242.296            True
#                        job_title_AI Product Manager             95.307            150.188            True
#                          job_title_AI Product Owner           -866.189           -819.934            True
#                             job_title_AI Programmer           -526.446           -489.847            True
#                      job_title_AI Research Engineer           -609.795           -576.860            True
#                     job_title_AI Research Scientist           -637.328           -603.603            True
#                             job_title_AI Researcher            -23.530             72.366            True
#                              job_title_AI Scientist          -1051.154           -938.111            True
#          job_title_AI Software Development Engineer           -336.971           -324.812            True
#                      job_title_AI Software Engineer           -286.523           -247.901            True
#                     job_title_AI Solution Architect           -411.953           -375.313            True
#                   job_title_AI Solutions Specialist           -436.723           -412.433            True
#                             job_title_AI Specialist          -2031.897          -1931.407            True
#                             job_title_AI Strategist           -549.360           -525.952            True
#                              job_title_AI Tech Lead           -301.480           -275.353            True
#                        job_title_AWS Data Architect              0.000              0.000           False
#                         job_title_Account Executive          -1738.125          -1662.241            True
#                         job_title_Actuarial Analyst          -1282.217          -1241.913            True
#                                   job_title_Actuary           -989.596           -935.086            True
#                      job_title_Admin & Data Analyst           -525.357           -499.078            True
#                     job_title_Advanced Data Analyst           -311.242           -299.069            True
#                       job_title_Algorithm Developer           -346.622           -303.283            True
#                                job_title_Alternance           -444.188           -426.448            True
#                                   job_title_Analyst         -14380.123         -13832.126            True
#                         job_title_Analytics Analyst           -302.795           -290.574            True
#                        job_title_Analytics Engineer          -5305.422          -4912.465            True
#             job_title_Analytics Engineering Manager            922.723            933.315            True
#                            job_title_Analytics Lead          -1825.943          -1722.629            True
#                      job_title_Analytics Specialist          -2012.590          -1938.791            True
#                     job_title_Application Developer          -1361.014          -1306.687            True
#                        job_title_Applied AI ML Lead            434.879            450.078            True
#                    job_title_Applied Data Scientist           -811.503           -769.550            True
#         job_title_Applied Machine Learning Engineer           -327.209           -306.628            True
#        job_title_Applied Machine Learning Scientist           -967.247           -923.663            True
#                job_title_Applied Research Scientist              0.000             -0.000           False
#                         job_title_Applied Scientist          -1048.881           -789.372            True
#                                 job_title_Architect          -1993.732          -1755.416            True
#          job_title_Artificial Intelligence Engineer          -1524.273          -1459.212            True
#                                 job_title_Associate          -7478.080          -7101.105            True
#                       job_title_Automation Engineer          -1306.808          -1256.534            True
#             job_title_Autonomous Vehicle Technician           -111.467            -94.680            True
#                       job_title_Azure Data Engineer           -283.771           -264.887            True
#                         job_title_BI & Data Analyst           -265.469           -253.198            True
#                                job_title_BI Analyst          -3940.259          -3795.204            True
#                           job_title_BI Data Analyst          -1574.768          -1524.293            True
#                          job_title_BI Data Engineer           -439.271           -427.135            True
#                              job_title_BI Developer          -4617.058          -4455.255            True
#                               job_title_BI Engineer          -2700.210          -2593.388            True
#                         job_title_Backend Developer           -860.386           -827.420            True
#                          job_title_Backend Engineer           -956.226           -789.652            True
#                 job_title_Backend Software Engineer           -238.614           -225.702            True
#                             job_title_Bear Robotics           -445.197           -412.043            True
#                          job_title_Big Data Analyst            -85.476           -316.313            True
#                        job_title_Big Data Architect           -274.309           -257.414            True
#                        job_title_Big Data Developer           -889.279           -850.377            True
#                         job_title_Big Data Engineer           -915.138           -871.976            True
#                          job_title_Bioinformatician          -2031.731          -1960.581            True
#                  job_title_Bioinformatics Scientist          -2003.120          -1915.161            True
#                 job_title_Bioinformatics Specialist           -365.178           -341.329            True
#                          job_title_Business Analyst          -5245.992          -5048.390            True
#                     job_title_Business Data Analyst          -1411.171          -1358.626            True
#              job_title_Business Development Manager           -306.944           -294.767            True
#       job_title_Business Development Representative          -1223.231          -1186.286            True
#                 job_title_Business Insights Manager            -88.986            -76.597            True
#                     job_title_Business Intelligence          -4216.551          -4026.606            True
#             job_title_Business Intelligence Analyst          -6621.678          -6366.766            True
#          job_title_Business Intelligence Consultant           -704.993           -687.422            True
#        job_title_Business Intelligence Data Analyst           -463.897           -446.968            True
#           job_title_Business Intelligence Developer          -5813.879          -5611.923            True
#            job_title_Business Intelligence Engineer          -5138.860          -4920.846            True
#                job_title_Business Intelligence Lead          -1390.174          -1327.177            True
#             job_title_Business Intelligence Manager          -1105.924          -1040.691            True
#          job_title_Business Intelligence Specialist          -1727.063          -1663.969            True
#                          job_title_CRM Data Analyst           -366.174           -354.142            True
#                         job_title_Chatbot Developer           -569.795           -541.277            True
#                 job_title_Cheminformatics Scientist           -401.891           -384.867            True
#                        job_title_Cientista de Dados           -407.074           -394.778            True
#                             job_title_Clinical Aide           -956.805           -935.820            True
#                    job_title_Clinical Data Operator          -1029.160          -1008.640            True
#                           job_title_Cloud Architect           -302.234           -285.446            True
#                      job_title_Cloud Data Architect            140.324            150.834            True
#                       job_title_Cloud Data Engineer           -258.743           -235.222            True
#              job_title_Cloud Database Administrator          -1394.618          -1338.082            True
#                   job_title_Cloud Database Engineer          -1534.901          -1466.788            True
#                           job_title_Cloud Developer           -417.851           -377.492            True
#                            job_title_Cloud Engineer          -2785.246          -2644.896            True
#                   job_title_Compliance Data Analyst           -491.354           -474.420            True
#                   job_title_Computational Biologist          -1619.055          -1531.640            True
#                   job_title_Computational Scientist           -858.622           -815.417            True
#                  job_title_Computer Vision Engineer           -977.731           -851.574            True
#         job_title_Computer Vision Software Engineer           -744.179           -717.825            True
#                                job_title_Consultant          -7393.071          -7095.073            True
#                  job_title_Consultant Data Engineer           -379.767           -362.070            True
#                         job_title_Controls Engineer           -244.376           -232.214            True
#                job_title_Conversational AI Designer           -411.953           -395.044            True
#                                job_title_Copywriter           -722.015           -691.087            True
#                     job_title_Creative Technologist           -721.700           -698.174            True
#                 job_title_Customer Success Engineer           -348.762           -336.413            True
#                  job_title_Customer Success Manager              0.000             -0.000           False
#                  job_title_Data & Analytics Analyst           -150.566           -138.577            True
#                              job_title_Data Analist           -548.386           -516.362            True
#                             job_title_Data Analysis          -1903.176          -1832.212            True
#                  job_title_Data Analysis Specialist           -448.558           -431.650            True
#                              job_title_Data Analyst         -22159.301         -21324.805            True
#                         job_title_Data Analyst Lead           -340.305           -323.163            True
#                  job_title_Data Analytics Associate          -1063.299          -1036.656            True
#           job_title_Data Analytics Business Partner           -691.121           -662.496            True
#                 job_title_Data Analytics Consultant          -2145.466          -2079.159            True
#                  job_title_Data Analytics Developer          -1056.937          -1016.816            True
#                   job_title_Data Analytics Engineer           -730.350           -700.942            True
#                       job_title_Data Analytics Lead          -1899.787          -1790.379            True
#                    job_title_Data Analytics Manager          -2879.808          -2723.162            True
#                 job_title_Data Analytics Specialist          -2633.273          -2540.877            True
#                  job_title_Data Analytics Team Lead           -246.603           -229.815            True
#                            job_title_Data Architect          -5894.045          -5514.611            True
#                            job_title_Data Archivist           -199.775           -182.864            True
#                           job_title_Data Consultant          -1059.232          -1012.714            True
#                      job_title_Data DevOps Engineer           -609.976           -587.880            True
#                            job_title_Data Developer          -2990.386          -2872.807            True
#                             job_title_Data Engineer         -14798.812         -13926.683            True
#                           job_title_Data Governance          -3383.000          -3203.567            True
#                   job_title_Data Governance Analyst          -3574.882          -3432.226            True
#                 job_title_Data Governance Architect           -534.722           -517.939            True
#                job_title_Data Governance Consultant           -685.805           -656.668            True
#                  job_title_Data Governance Engineer          -1022.961           -971.159            True
#                      job_title_Data Governance Lead          -1980.946          -1864.529            True
#                   job_title_Data Governance Manager          -1324.530          -1240.630            True
#                job_title_Data Governance Specialist          -2643.265          -2545.158            True
#              job_title_Data Infrastructure Engineer           -323.256           -219.628            True
#                  job_title_Data Integration Analyst          -1217.240          -1173.762            True
#              job_title_Data Integration Coordinator           -676.201           -659.297            True
#                job_title_Data Integration Developer           -908.920           -865.562            True
#                 job_title_Data Integration Engineer          -2348.342          -2252.902            True
#                     job_title_Data Integration Lead           -722.238           -704.669            True
#               job_title_Data Integration Specialist          -2359.617          -2272.115            True
#                           job_title_Data Integrator           -765.842           -728.924            True
#                    job_title_Data Integrity Analyst           -952.038           -911.847            True
#                 job_title_Data Integrity Specialist          -1178.420          -1147.477            True
#                                 job_title_Data Lead          -2952.835          -2795.126            True
#                           job_title_Data Management          -2087.365          -2002.952            True
#                   job_title_Data Management Analyst          -4851.063          -4680.978            True
#                 job_title_Data Management Associate          -1580.998          -1531.599            True
#                job_title_Data Management Consultant          -1191.105          -1149.296            True
#               job_title_Data Management Coordinator           -891.924           -875.146            True
#                    job_title_Data Management Expert           -250.726           -233.060            True
#                      job_title_Data Management Lead          -1756.874          -1675.734            True
#                   job_title_Data Management Manager           -477.118           -450.755            True
#                job_title_Data Management Specialist          -5009.060          -4859.540            True
#                              job_title_Data Manager          -8530.394          -8241.064            True
#                              job_title_Data Modeler          -2979.659          -2843.633            True
#                           job_title_Data Operations          -1112.003          -1044.785            True
#                   job_title_Data Operations Analyst          -3548.052          -3435.966            True
#                 job_title_Data Operations Associate          -1647.043          -1599.111            True
#                  job_title_Data Operations Engineer          -2158.778          -2068.461            True
#                      job_title_Data Operations Lead           -611.841           -575.032            True
#                   job_title_Data Operations Manager           -606.024           -539.463            True
#                job_title_Data Operations Specialist          -2653.530          -2582.419            True
#                             job_title_Data Operator           -578.460           -566.275            True
#                    job_title_Data Pipeline Engineer           -232.695           -215.907            True
#                    job_title_Data Platform Engineer          -1154.495          -1079.897            True
#                      job_title_Data Product Analyst           -203.039           -186.201            True
#                         job_title_Data Product Lead            -79.849            -63.058            True
#                      job_title_Data Product Manager          -2675.986          -2506.562            True
#                        job_title_Data Product Owner          -2333.376          -2211.606            True
#                      job_title_Data Quality Analyst          -3904.690          -3772.161            True
#                     job_title_Data Quality Engineer          -2083.728          -2006.439            True
#                       job_title_Data Quality Expert             -0.000             -0.000           False
#                         job_title_Data Quality Lead          -1555.629          -1487.623            True
#                      job_title_Data Quality Manager          -1054.836          -1011.268            True
#                   job_title_Data Quality Specialist          -1469.738          -1416.603            True
#                             job_title_Data Reporter          -1088.176          -1057.193            True
#                    job_title_Data Reporting Analyst          -3314.081          -3228.396            True
#                 job_title_Data Reporting Specialist          -1024.034          -1000.548            True
#                    job_title_Data Science Tech Lead            632.042            642.560            True
#                            job_title_Data Scientist         -12917.665         -12041.060            True
#                  job_title_Data Scientist Associate           -468.315           -456.128            True
#                     job_title_Data Scientist Expert            -78.456            -66.347            True
#                       job_title_Data Scientist Lead           -179.067           -158.587            True
#                    job_title_Data Scientist Manager           -324.840           -308.075            True
#                           job_title_Data Specialist          -9116.110          -8837.525            True
#                              job_title_Data Steward           -242.544           -218.752            True
#                           job_title_Data Strategist          -2293.396          -2189.553            True
#                        job_title_Data Strategy Lead           -653.927           -603.573            True
#                     job_title_Data Strategy Manager           -728.213           -699.333            True
#                            job_title_Data Team Lead          -1144.545          -1084.595            True
#                job_title_Data Visualization Analyst          -1940.542          -1873.368            True
#               job_title_Data Visualization Designer          -1335.446          -1302.327            True
#              job_title_Data Visualization Developer          -1267.473          -1213.222            True
#               job_title_Data Visualization Engineer          -1412.378          -1320.049            True
#                 job_title_Data Visualization Expert           -491.380           -474.596            True
#             job_title_Data Visualization Specialist          -2559.184          -2474.118            True
#             job_title_Data and Analytics Consultant           -763.781           -735.225            True
#                job_title_Data and Reporting Analyst          -1653.014          -1601.347            True
#           job_title_Data and Reporting Professional          -1745.034          -1701.643            True
#                          job_title_DataOps Engineer          -1166.153          -1113.364            True
#                    job_title_Database Administrator          -1077.399          -1029.586            True
#                       job_title_Databricks Engineer           -192.179           -175.390            True
#                        job_title_Decision Scientist          -2404.949          -2276.822            True
#                    job_title_Deep Learning Engineer           -300.043           -263.070            True
#                  job_title_Deep Learning Researcher           -149.768           -137.582            True
#                           job_title_DevOps Engineer          -3809.767          -3598.044            True
#                               job_title_DevOps Lead             31.552             45.945            True
#                                 job_title_Developer          -5965.633          -5691.618            True
#                        job_title_Developer Advocate           -515.914           -483.079            True
#                                  job_title_Director          -1178.815           -999.732            True
#         job_title_Director of Business Intelligence           -379.647           -361.937            True
#              job_title_Director of Machine Learning            584.333            638.949            True
#            job_title_Director of Product Management            516.190            565.759            True
#                             job_title_ETL Developer          -1873.381          -1801.593            True
#                              job_title_ETL Engineer           -907.157           -876.032            True
#                                 job_title_Economist           -360.319           -323.680            True
#               job_title_Elasticsearch Administrator           -430.179           -412.601            True
#    job_title_Encounter Data Management Professional          -2556.812          -2495.734            True
#                                  job_title_Engineer          -8065.926          -7375.440            True
#                       job_title_Engineering Manager           4712.208           4955.742            True
#              job_title_Enterprise Account Executive            737.569            792.296            True
#                                 job_title_Executive          -1308.879          -1225.693            True
#       job_title_Experienced Quantitative Strategist           -218.787           -201.999            True
#                      job_title_Finance Data Analyst           -110.878            -90.353            True
#                    job_title_Financial Data Analyst           -641.887           -618.080            True
#                         job_title_Frontend Engineer           -404.541           -369.387            True
#                      job_title_Full Stack Developer          -2501.575          -2383.356            True
#                       job_title_Full Stack Engineer          -2185.535          -2040.294            True
#                        job_title_Fullstack Engineer           -513.905           -467.686            True
#                           job_title_GenAI Architect             97.136            118.953            True
#                                job_title_Head of AI            229.238            308.217            True
#                        job_title_Head of Applied AI            428.094            455.291            True
#             job_title_Head of Business Intelligence              0.000             -0.000           False
#                              job_title_Head of Data           -240.931            -69.890            True
#                  job_title_Head of Machine Learning            602.186            642.369            True
#                         job_title_Head of Marketing           -184.943           -168.025            True
#                   job_title_Infrastructure Engineer           -226.879           -180.674            True
#                           job_title_Insight Analyst          -2798.459          -2682.909            True
#                    job_title_Integration Specialist           -161.612           -144.701            True
#                            job_title_Java Developer           -925.591           -888.623            True
#                              job_title_LLM Engineer           -306.933           -294.750            True
#                          job_title_Lead AI Engineer              0.000             -0.000           False
#                              job_title_Lead Analyst          -1081.527          -1019.685            True
#                        job_title_Lead Data Analysis           -394.682           -373.906            True
#                         job_title_Lead Data Analyst           -531.434           -501.188            True
#                        job_title_Lead Data Engineer           -521.801           -490.573            True
#                      job_title_Lead Data Management           -610.987           -594.205            True
#                       job_title_Lead Data Scientist           -631.395           -593.010            True
#                             job_title_Lead Engineer           -977.338           -879.748            True
#            job_title_Lead Machine Learning Engineer           -577.074           -549.934            True
#                job_title_ML Infrastructure Engineer            210.739            254.989            True
#                              job_title_ML Scientist           -514.930           -450.820            True
#                            job_title_MLOps Engineer          -1917.138          -1778.278            True
#                job_title_Machine Learning Architect            407.699            461.989            True
#                job_title_Machine Learning Developer          -1284.067          -1211.745            True
#                 job_title_Machine Learning Engineer          -1358.414           -725.641            True
#  job_title_Machine Learning Infrastructure Engineer           -564.408           -490.739            True
#                     job_title_Machine Learning Lead           -589.401           -552.767            True
#                  job_title_Machine Learning Manager            200.370            240.279            True
#           job_title_Machine Learning Model Engineer            236.085            262.630            True
#                  job_title_Machine Learning Modeler           -207.496           -174.538            True
#     job_title_Machine Learning Performance Engineer            267.985            283.181            True
#        job_title_Machine Learning Platform Engineer            206.470            248.135            True
#         job_title_Machine Learning Quality Engineer           -444.209           -411.007            True
#        job_title_Machine Learning Research Engineer           -686.011           -659.037            True
#               job_title_Machine Learning Researcher           -564.963           -449.437            True
#                job_title_Machine Learning Scientist          -1679.900          -1477.255            True
#        job_title_Machine Learning Software Engineer           -185.748           -140.581            True
#               job_title_Machine Learning Specialist           -906.563           -856.105            True
#                job_title_Machine Learning Tech Lead           -171.779           -154.990            True
#                   job_title_Machine Vision Engineer           -690.098           -672.405            True
#                                   job_title_Manager          -5973.858          -5341.425            True
#                   job_title_Manager Data Management           -456.692           -439.869            True
#                         job_title_Marketing Analyst           -580.381           -562.808            True
#               job_title_Marketing Analytics Manager           -481.491           -464.585            True
#                    job_title_Marketing Data Analyst           -305.036           -287.178            True
#                   job_title_Marketing Data Engineer           -255.783           -243.650            True
#                  job_title_Marketing Data Scientist              0.000             -0.000           False
#                 job_title_Marketing Science Partner           -391.749           -367.851            True
#                    job_title_Master Data Management          -1192.346          -1140.466            True
#                    job_title_Master Data Specialist           -589.972           -573.068            True
#                 job_title_Member of Technical Staff           -703.489           -613.606            True
#                              job_title_NLP Engineer           -873.900           -823.410            True
#                          job_title_Network Engineer           -203.901           -191.679            True
#                       job_title_People Data Analyst           -429.846           -417.640            True
#                    job_title_Platform Data Engineer              0.000             -0.000           False
#                         job_title_Platform Engineer          -2426.645          -2210.968            True
#                      job_title_Post Doctoral Fellow           -524.751           -507.176            True
#                       job_title_Postdoctoral Fellow          -2597.355          -2519.871            True
#              job_title_Postdoctoral Research Fellow           -481.363           -464.341            True
#                   job_title_Postdoctoral Researcher          -1551.644          -1488.281            True
#                                  job_title_Power BI          -1862.513          -1799.578            True
#                    job_title_Power BI Administrator           -943.395           -903.075            True
#                        job_title_Power BI Architect           -413.490           -395.912            True
#                       job_title_Power BI Consultant           -636.011           -618.440            True
#                        job_title_Power BI Developer          -3538.721          -3423.536            True
#                           job_title_Power BI Expert           -538.553           -505.423            True
#                       job_title_Power BI Specialist           -752.409           -721.372            True
#                           job_title_Pricing Analyst          -1008.801           -968.363            True
# job_title_Principal Application Delivery Consultant           -508.061           -490.486            True
#                    job_title_Principal Data Analyst           -363.983           -347.078            True
#                  job_title_Principal Data Architect              0.000              0.000           False
#                   job_title_Principal Data Engineer           -181.882           -161.483            True
#                  job_title_Principal Data Scientist             45.252             80.350            True
#                        job_title_Principal Engineer           -404.162           -355.177            True
#       job_title_Principal Machine Learning Engineer           -141.410           -120.988            True
#                      job_title_Principal Researcher           -229.736           -186.418            True
#                       job_title_Principal Scientist            -40.111              1.260            True
#              job_title_Principal Software Architect           -198.035           -169.143            True
#          job_title_Principal Statistical Programmer           -636.232           -570.324            True
#                           job_title_Product Analyst          -3021.186          -2877.037            True
#                      job_title_Product Data Analyst           -762.970           -733.724            True
#                          job_title_Product Designer           -878.531           -754.124            True
#                           job_title_Product Manager          -1618.482          -1231.454            True
#                             job_title_Product Owner          -1835.936          -1730.222            True
#                        job_title_Product Specialist          -1043.106           -988.722            True
#                           job_title_Prompt Engineer          -1426.949          -1329.084            True
#                           job_title_Psychometrician           -495.392           -477.693            True
#                          job_title_Python Developer          -2517.729          -2416.400            True
#                               job_title_QA Engineer          -1907.732          -1809.781            True
#                      job_title_Quant Options Trader           -100.107            -67.182            True
#                              job_title_Quant Trader           -183.722           -171.514            True
#                      job_title_Quantitative Analyst          -2495.326          -2363.466            True
#                    job_title_Quantitative Developer            -75.770            -18.114            True
#             job_title_Quantitative Research Analyst           -474.675           -462.540            True
#                   job_title_Quantitative Researcher           -293.949           -200.483            True
#                       job_title_Quantitative Trader            130.451            145.767            True
#                             job_title_RPA Developer           -423.079           -406.172            True
#                          job_title_Research Analyst          -5130.245          -4926.700            True
#                        job_title_Research Assistant          -4044.049          -3941.272            True
#                        job_title_Research Associate          -4609.494          -4463.268            True
#                     job_title_Research Data Manager              0.000             -0.000           False
#                         job_title_Research Engineer            358.727            683.866            True
#                     job_title_Research Professional           -981.185           -957.351            True
#                        job_title_Research Scientist           -329.665             69.987            True
#                        job_title_Research Team Lead           1922.982           1937.433            True
#                                job_title_Researcher          -1056.014           -950.482            True
#                              job_title_Risk Analyst           -770.380           -731.654            True
#                         job_title_Robotics Engineer          -1699.474          -1606.383            True
#                job_title_Robotics Software Engineer             17.669             55.829            True
#                             job_title_SAS Developer            -31.466            -13.876            True
#         job_title_Safety Data Management Specialist           -244.819           -232.635            True
#                        job_title_Sales Data Analyst           -205.983           -193.651            True
#          job_title_Sales Development Representative          -1642.847          -1599.303            True
#                            job_title_Sales Engineer           -667.123           -620.817            True
#                  job_title_Salesforce Administrator           -105.981            -89.069            True
#                     job_title_Scala Spark Developer           -365.885           -342.033            True
#                         job_title_Security Engineer           -362.976           -286.055            True
#                       job_title_Security Researcher           -245.642           -193.964            True
#                 job_title_Site Reliability Engineer          -1146.260           -948.986            True
#                        job_title_Software Architect           -418.328           -341.518            True
#                    job_title_Software Data Engineer           -533.632           -513.117            True
#                        job_title_Software Developer          -4811.572          -4564.685            True
#             job_title_Software Development Director           -200.798           -183.880            True
#             job_title_Software Development Engineer          -2066.049          -1843.661            True
#                         job_title_Software Engineer          -4580.451          -3846.987            True
#                        job_title_Solution Architect          -1967.593          -1806.757            True
#                         job_title_Solution Engineer          -1074.557           -999.000            True
#                       job_title_Solutions Architect          -2101.354          -1879.284            True
#                        job_title_Solutions Engineer          -2173.805          -1999.278            True
#                        job_title_Staff Data Analyst           -806.909           -784.682            True
#                      job_title_Staff Data Scientist           -554.117           -533.741            True
#           job_title_Staff Machine Learning Engineer           -115.370           -103.264            True
#                                     job_title_Stage          -1148.444          -1100.377            True
#                    job_title_Statistical Programmer          -2558.513          -2453.555            True
#                              job_title_Statistician          -2848.573          -2741.701            True
#                      job_title_System Administrator           -585.927           -562.143            True
#                           job_title_System Engineer          -1311.384          -1231.886            True
#                     job_title_Systems Administrator           -953.139           -912.953            True
#                          job_title_Systems Engineer          -2744.268          -2490.342            True
#                         job_title_Tableau Developer           -947.634           -914.688            True
#                                 job_title_Tech Lead            -23.358             41.650            True
#                            job_title_Tech Lead Data           -359.185           -341.493            True
#                       job_title_Technical Architect           -648.008           -597.664            True
#                            job_title_Technical Lead           -919.232           -775.802            True
#                       job_title_Technical Recruiter           -414.279           -380.882            True
#                      job_title_Technical Specialist           -700.169           -658.245            True
#                job_title_Technical Support Engineer          -1055.848          -1011.034            True
#              job_title_Technical Support Specialist          -1160.931          -1129.875            True
#                          job_title_Technical Writer           -724.409           -664.515            True
#                     job_title_Technology Integrator           -866.443           -829.422            True
#                                   job_title_Trainee           -896.910           -866.034            True
#                             job_title_Web Developer           -790.842           -759.932            True
#                                 company_location_AE            -11.217           -536.350            True
#                                 company_location_AM           -135.336           -701.907            True
#                                 company_location_AR            366.749          -1293.481            True
#                                 company_location_AS           -142.918           -571.404            True
#                                 company_location_AT           -247.182          -2948.488            True
#                                 company_location_AU           5991.752           1444.753            True
#                                 company_location_BA           -203.882           -505.943            True
#                                 company_location_BE            316.797           -776.332            True
#                                 company_location_BG            279.064           -199.807            True
#                                 company_location_BR           -326.143          -2325.313            True
#                                 company_location_BS           -170.648           -384.864            True
#                                 company_location_CA          12617.147           -476.136            True
#                                 company_location_CD            -49.350             -0.000           False
#                                 company_location_CF              0.000             -0.000           False
#                                 company_location_CH           1223.829           -148.899            True
#                                 company_location_CL            -63.223           -997.492            True
#                                 company_location_CN             42.428           -171.284            True
#                                 company_location_CO           -111.114          -1432.317            True
#                                 company_location_CR           -520.341          -1044.944            True
#                                 company_location_CY           -104.429           -876.803            True
#                                 company_location_CZ           1179.271            404.487            True
#                                 company_location_DE           2054.068          -1948.836            True
#                                 company_location_DK            102.773           -504.343            True
#                                 company_location_DO             -3.043           -373.866            True
#                                 company_location_DZ            180.921           -247.302            True
#                                 company_location_EC           -196.868           -721.166            True
#                                 company_location_EE           -312.535          -1114.353            True
#                                 company_location_EG            822.477           -516.165            True
#                                 company_location_ES           -322.271          -3227.676            True
#                                 company_location_FI            110.001          -1295.941            True
#                                 company_location_FR            589.802          -2882.446            True
#                                 company_location_GB           6053.638          -4573.878            True
#                                 company_location_GH           -129.761           -500.601            True
#                                 company_location_GI             94.488           -119.400            True
#                                 company_location_GR           -384.039          -1389.383            True
#                                 company_location_HK            279.542           -199.496            True
#                                 company_location_HN            189.879           -181.161            True
#                                 company_location_HR           -248.375           -727.135            True
#                                 company_location_HU           -188.849           -831.530            True
#                                 company_location_ID            120.565           -358.107            True
#                                 company_location_IE           1450.547           -817.077            True
#                                 company_location_IL            892.894            179.262            True
#                                 company_location_IN          -1255.784          -4185.061            True
#                                 company_location_IQ              0.000             -0.000           False
#                                 company_location_IR             57.475           -156.270            True
#                                 company_location_IT            431.698          -1172.511            True
#                                 company_location_JM            287.597           -318.279            True
#                                 company_location_JO             82.470           -220.258            True
#                                 company_location_JP            417.665           -813.242            True
#                                 company_location_KE            234.661           -331.895            True
#                                 company_location_KR            279.643           -462.484            True
#                                 company_location_LB            663.870            -13.265            True
#                                 company_location_LS            -33.359           -335.921            True
#                                 company_location_LT           -710.821          -4349.341            True
#                                 company_location_LU            140.478           -425.998            True
#                                 company_location_LV           -401.672          -2366.028            True
#                                 company_location_MD           -113.259           -327.131            True
#                                 company_location_MK           -286.623           -892.604            True
#                                 company_location_MT            197.258           -686.141            True
#                                 company_location_MU            233.743             16.408            True
#                                 company_location_MX            655.484          -1474.134            True
#                                 company_location_MY            -81.746           -384.346            True
#                                 company_location_NG             42.182           -636.412            True
#                                 company_location_NL           1219.696          -2748.515            True
#                                 company_location_NO           -115.757           -720.840            True
#                                 company_location_NZ           1790.286            198.666            True
#                                 company_location_OM              0.000             -0.000           False
#                                 company_location_PA             96.639           -205.214            True
#                                 company_location_PE             13.272           -415.342            True
#                                 company_location_PH           -211.122          -1756.616            True
#                                 company_location_PK            -51.147           -421.839            True
#                                 company_location_PL           -359.755          -2812.280            True
#                                 company_location_PR            849.681            170.250            True
#                                 company_location_PT           -498.671          -2145.177            True
#                                 company_location_QA            864.580            649.283            True
#                                 company_location_RO           -172.338           -815.263            True
#                                 company_location_RS             18.366           -460.362            True
#                                 company_location_RU           -296.725           -863.012            True
#                                 company_location_SA            730.182            356.254            True
#                                 company_location_SE            228.389           -544.011            True
#                                 company_location_SG            840.868           -293.702            True
#                                 company_location_SI           -226.408           -868.533            True
#                                 company_location_SK           -534.731          -2751.492            True
#                                 company_location_SV            -76.950           -555.669            True
#                                 company_location_TH           -355.968           -726.290            True
#                                 company_location_TR           -464.705          -1492.565            True
#                                 company_location_TW           -386.884          -1159.641            True
#                                 company_location_UA             75.025           -808.609            True
#                                 company_location_US          29392.709           9381.967            True
#                                 company_location_VE            784.855            480.744            True
#                                 company_location_VN           -236.918           -607.519            True
#                                 company_location_XK              0.000             -0.000           False
#                                 company_location_ZA             34.677          -1540.007            True
#                                 company_location_ZM              0.000             -0.000           False
#
# 📊 Lasso selected 470 out of 486 features
# Features with coefficient = 0 are considered unimportant by Lasso
#
# 💡 With one-hot encoding:
# - Lasso might select only some categories from a feature
# - This helps identify which specific categories matter most

# %% [markdown]
# ### 💡 Troubleshooting Tips
#
# **If you get errors with Linear Regression:**
#
# 1. **"Singular matrix" or "LinAlgError"**:
#    - Use Ridge or Lasso instead
#    - Remove highly correlated features
#    - Reduce the number of features
#
# 2. **Poor performance (low R² score)**:
#    - Try regularized models (Ridge/Lasso)
#    - Add more relevant features
#    - Check for outliers in your data
#
# 3. **"Convergence warnings"**:
#    - Increase `max_iter` parameter
#    - Try Ridge regression instead
#    - Standardize your features first
#
# **Remember**: Ridge and Lasso are more robust than basic Linear Regression!

# %% [markdown]
# ## 🔬 Experiment with Preprocessing Choices
#
# **Now that you've completed the analysis, try these experiments:**
#
# ### Encoding Experiments:
# 1. **Change `ENCODING_METHOD`** from "one_hot" to "label" (or vice versa)
# 2. **Re-run all cells** from Section 3 onwards
# 3. **Compare results:** Which encoding gives better R² scores?
#
# ### Scaling Experiments:
# 1. **Change `APPLY_SCALING`** from True to False (or vice versa)
# 2. **Re-run from Section 3** onwards
# 3. **Notice:** How much does scaling affect Linear/Ridge/Lasso vs Tree-based models?
#
# ### Expected Observations:
# - **Linear models** (Linear/Ridge/Lasso) are very sensitive to scaling
# - **Tree models** (Decision Tree/Random Forest) are less affected by scaling
# - **One-hot encoding** creates more features but treats categories independently
# - **Label encoding** assumes ordinal relationships between categories
#
# ### Questions to Explore:
# 1. Which combination gives the best performance for your data?
# 2. How does the number of features change with different encoding?
# 3. Which features does Lasso select with each encoding method?
# 4. Do the feature importance rankings change?
#
# **Pro Tip:** The best preprocessing depends on your specific data and problem!
